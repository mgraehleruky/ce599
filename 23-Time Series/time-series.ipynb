# %% [markdown]
# # Time-Series Modeling
#
# This lesson is adapted from Sean Abu:
#
# http://www.seanabu.com/2016/03/22/time-series-seasonal-ARIMA-model-in-python/
#
# With examples from Forecasting Principles and Practice, by Hyndman and Athanastopoulos:
#
# https://www.otexts.org/fpp
#
# The latter is an excellent text book and worth checking out.  I also recommend their fpp package for R, which provides some nice functionality to auto-select the order of an ARIMA model.
#
# ### Basics
#
# A time-series is a series of data points indexed in time order.  It is naturally one-dimensional, and for our purposes we will consider that all points are equally spaced.
#
# We may want to model time series for either inference (understanding statistical relationships), or for forecasting.  We may select different approaches depending on our interest.  There are two main approaches we will consider here:
#
# 1. Regression on time-series data. This is about predicting a time series based on exogenous variables.
# 2. ARIMA modeling.  This is about predicting a time series as a function of its past values.
#
# We can also combine the two: ARIMA models with exogenous regressors.
#
# The focus today is on the modeling.  Pandas provides some nice data wrangling methods for working with time series data which are documented here:
#
# http://pandas.pydata.org/pandas-docs/stable/timeseries.html

# %% [markdown]
# ### Regression on time-series data

# %%
# %matplotlib inline

import pandas as pd
import seaborn as sns
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
# This data has
air = pd.read_csv('data/ausair.csv', parse_dates=['YEAR'], index_col='YEAR')
air
# Out:
#                AUSAIR  GUINEARICE
# YEAR
# 1970-01-01   7.318700    0.311405
# 1971-01-01   7.326600    0.325180
# 1972-01-01   7.795600    0.339565
# 1973-01-01   9.384600    0.354580
# 1974-01-01  10.664700    0.370265
# 1975-01-01  11.055100    0.386640
# 1976-01-01  10.864300    0.403740
# 1977-01-01  11.306500    0.421600
# 1978-01-01  12.122300    0.440250
# 1979-01-01  13.022500    0.459720
# 1980-01-01  13.648800    0.480055
# 1981-01-01  13.219500    0.501290
# 1982-01-01  13.187900    0.523460
# 1983-01-01  12.601500    0.546610
# 1984-01-01  13.236800    0.570790
# 1985-01-01  14.412100    0.596035
# 1986-01-01  15.497300    0.622395
# 1987-01-01  16.880200    0.649925
# 1988-01-01  18.816300    0.678670
# 1989-01-01  15.114300    0.708690
# 1990-01-01  17.553400    0.740035
# 1991-01-01  21.860100    0.772765
# 1992-01-01  23.886600    0.806945
# 1993-01-01  26.929300    0.842635
# 1994-01-01  26.888500    0.879905
# 1995-01-01  28.831400    0.918825
# 1996-01-01  30.075100    0.959460
# 1997-01-01  30.953500    1.001900
# 1998-01-01  30.185700    1.046220
# 1999-01-01  31.579700    1.092490
# 2000-01-01  32.577569    1.140810
# 2001-01-01  33.477398    1.033520
# 2002-01-01  39.021581    1.088670
# 2003-01-01  41.386432    1.146760
# 2004-01-01  41.596552    1.207960
# 2005-01-01  44.657324    1.272420
# 2006-01-01  46.951775    1.340310
# 2007-01-01  48.728837    1.401590
# 2008-01-01  51.488427    1.534090
# 2009-01-01  50.026967    1.499000

# %%
# Both time series are growing over the period of interest...

air.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000000001BAC4898>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000001BAFBFD0>],
#       dtype=object)

# %%
# when we plot them against each other, they look to be highly correlated...

sns.jointplot(x="GUINEARICE", y="AUSAIR", data=air)

# %%
# so let's estimate a regression model

mod = smf.ols(formula='AUSAIR ~ GUINEARICE', data=air)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 AUSAIR   R-squared:                       0.971
# Model:                            OLS   Adj. R-squared:                  0.970
# Method:                 Least Squares   F-statistic:                     1272.
# Date:                Mon, 16 Apr 2018   Prob (F-statistic):           7.94e-31
# Time:                        08:09:24   Log-Likelihood:                -89.643
# No. Observations:                  40   AIC:                             183.3
# Df Residuals:                      38   BIC:                             186.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -5.7297      0.903     -6.348      0.000      -7.557      -3.902
# GUINEARICE    37.4101      1.049     35.672      0.000      35.287      39.533
# ==============================================================================
# Omnibus:                        1.905   Durbin-Watson:                   0.491
# Prob(Omnibus):                  0.386   Jarque-Bera (JB):                1.655
# Skew:                          -0.485   Prob(JB):                        0.437
# Kurtosis:                       2.774   Cond. No.                         4.73
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### Woohoo!  We got an r-squared of 0.97.  This is a great model!  Right?

# %% [markdown]
# Sorry to disappoint, but this is an example of **spurious regression**.  Spurious regression can happen when working with time series that are non-stationary.
#
# I would add that the model lacks a theoretical basis as well.  It clearly falls in the category of "If you can't explain it, you can't use it!"  However, spurious regression can occur even when there is a theoretical basis for the model.
#
# A stationary time series is one whose properties do not depend on the time at which the series is observed.  To avoid spurious regression, we want the dependent variable and all regressors to be stationary.

# %% [markdown]
# One way to tell if data are stationary is to plot them, and look for either a trend or a cycle

# %%
# check for trend or cycle

air.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000000001BD762E8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000001BD9FBA8>],
#       dtype=object)

# %% [markdown]
# We can also look at plots of the auto-correlation function (ACF).  auto-correlation is the correlation of the time-series past values.  There are some statistical tests for this as well, but often a graphical analysis is good enough.

# %%
# ACF plots

fig = sm.graphics.tsa.plot_acf(air['AUSAIR'], lags=30)
fig = sm.graphics.tsa.plot_acf(air['GUINEARICE'], lags=30)

# %% [markdown]
# What do we do if the data are not stationary?  There are a few strategies, but differencing usually works.  All this means is subtracting each value from the previous value.  That way, you are modeling the change, rather than the total value.

# %%
# shift moves things by the specified number of rows

air['AUSAIR_DIFF'] = air['AUSAIR'] - air['AUSAIR'].shift(1)  
air['GUINEARICE_DIFF'] = air['GUINEARICE'] - air['GUINEARICE'].shift(1)  
air.head()
# Out:
#              AUSAIR  GUINEARICE  AUSAIR_DIFF  GUINEARICE_DIFF
# YEAR
# 1970-01-01   7.3187    0.311405          NaN              NaN
# 1971-01-01   7.3266    0.325180       0.0079         0.013775
# 1972-01-01   7.7956    0.339565       0.4690         0.014385
# 1973-01-01   9.3846    0.354580       1.5890         0.015015
# 1974-01-01  10.6647    0.370265       1.2801         0.015685

# %%
# now does it look stationary? 

air.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000000001BF61908>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000001BEA0470>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000001BFACE10>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000001C022BE0>],
#       dtype=object)

# %%
# ACF plots
# the first row is missing, so skip that one..

fig = sm.graphics.tsa.plot_acf(air['AUSAIR_DIFF'][1:], lags=30)
fig = sm.graphics.tsa.plot_acf(air['GUINEARICE_DIFF'][1:], lags=30)

# %%
# if we have to, we can also calculate a second difference
# don't go beyond 2

air['AUSAIR_2DIFF'] = air['AUSAIR_DIFF'] - air['AUSAIR_DIFF'].shift(1)  
air['GUINEARICE_2DIFF'] = air['GUINEARICE_DIFF'] - air['GUINEARICE_DIFF'].shift(1)  
air.head()
# Out:
#              AUSAIR  GUINEARICE  AUSAIR_DIFF  GUINEARICE_DIFF  AUSAIR_2DIFF  \
# YEAR
# 1970-01-01   7.3187    0.311405          NaN              NaN           NaN
# 1971-01-01   7.3266    0.325180       0.0079         0.013775           NaN
# 1972-01-01   7.7956    0.339565       0.4690         0.014385        0.4611
# 1973-01-01   9.3846    0.354580       1.5890         0.015015        1.1200
# 1974-01-01  10.6647    0.370265       1.2801         0.015685       -0.3089
#
#             GUINEARICE_2DIFF
# YEAR
# 1970-01-01               NaN
# 1971-01-01               NaN
# 1972-01-01           0.00061
# 1973-01-01           0.00063
# 1974-01-01           0.00067

# %%
air.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000000001C308C50>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000001C291898>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000001C39DC50>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000001C3C7940>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000001C400828>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000001C400860>],
#       dtype=object)

# %%
# ACF plots
# the first two rows are missing, so skip those..

fig = sm.graphics.tsa.plot_acf(air['AUSAIR_2DIFF'][2:], lags=30)
fig = sm.graphics.tsa.plot_acf(air['GUINEARICE_2DIFF'][2:], lags=30)

# %%
# now what if we estimate the same model on the differenced data

mod = smf.ols(formula='AUSAIR_DIFF ~ GUINEARICE_DIFF', data=air)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            AUSAIR_DIFF   R-squared:                       0.125
# Model:                            OLS   Adj. R-squared:                  0.102
# Method:                 Least Squares   F-statistic:                     5.295
# Date:                Mon, 16 Apr 2018   Prob (F-statistic):             0.0271
# Time:                        08:09:29   Log-Likelihood:                -70.079
# No. Observations:                  39   AIC:                             144.2
# Df Residuals:                      37   BIC:                             147.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           0.5881      0.326      1.806      0.079      -0.072       1.248
# GUINEARICE_DIFF    16.6487      7.235      2.301      0.027       1.988      31.309
# ==============================================================================
# Omnibus:                        6.783   Durbin-Watson:                   1.733
# Prob(Omnibus):                  0.034   Jarque-Bera (JB):               10.436
# Skew:                          -0.123   Prob(JB):                      0.00542
# Kurtosis:                       5.522   Cond. No.                         30.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# now what if we estimate the same model on the second differenced data

mod = smf.ols(formula='AUSAIR_2DIFF ~ GUINEARICE_2DIFF', data=air)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           AUSAIR_2DIFF   R-squared:                       0.164
# Model:                            OLS   Adj. R-squared:                  0.141
# Method:                 Least Squares   F-statistic:                     7.088
# Date:                Mon, 16 Apr 2018   Prob (F-statistic):             0.0115
# Time:                        08:09:29   Log-Likelihood:                -79.187
# No. Observations:                  38   AIC:                             162.4
# Df Residuals:                      36   BIC:                             165.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           -0.0150      0.324     -0.046      0.963      -0.673       0.642
# GUINEARICE_2DIFF    18.3687      6.900      2.662      0.012       4.376      32.362
# ==============================================================================
# Omnibus:                        6.128   Durbin-Watson:                   2.672
# Prob(Omnibus):                  0.047   Jarque-Bera (JB):                8.413
# Skew:                           0.116   Prob(JB):                       0.0149
# Kurtosis:                       5.293   Cond. No.                         21.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Homework
#
# The data folder contains a time-series data set of ridership on the BART rail system from 2001 through 2015.  Estimate a regression model of the ridership (RIDERS) as a function of variables included in the data set.  Build as complete of a model as you can, but be sure you can explain it!

# %%
# This data has
bart = pd.read_csv('data/BARTEstimationFile.csv', parse_dates=['MONTH'], index_col='MONTH')
bart
# Out:
#                  RIDERS  STATIONS  CASH_FARE_2010USD_BART  \
# MONTH
# 2001-01-01  321180.5238        39                3.262745
# 2001-02-01  334885.1053        39                3.249754
# 2001-03-01  340021.5455        39                3.242376
# 2001-04-01  333794.4286        39                3.229546
# 2001-05-01  333847.4545        39                3.215007
# 2001-06-01  329447.8095        39                3.209588
# 2001-07-01  324565.6000        39                3.218629
# 2001-08-01  321757.9130        39                3.218629
# 2001-09-01  321320.8421        39                3.204188
# 2001-10-01  315571.1818        39                3.215007
# 2001-11-01  317824.9474        39                3.220444
# 2001-12-01  292390.7222        39                3.233202
# 2002-01-01  300937.5714        39                3.225899
# 2002-02-01  307748.1579        39                3.213199
# 2002-03-01  305536.8571        39                3.195228
# 2002-04-01  311872.9545        39                3.177457
# 2002-05-01  304468.2727        39                3.177457
# 2002-06-01  302729.9000        39                3.175690
# 2002-07-01  300920.6190        39                3.172164
# 2002-08-01  296473.0455        39                3.161631
# 2002-09-01  309639.7500        39                3.156391
# 2002-10-01  303796.3182        39                3.151168
# 2002-11-01  294359.9444        39                3.151168
# 2002-12-01  282622.3158        39                3.158136
# 2003-01-01  288637.6190        39                3.312243
# 2003-02-01  295525.4737        39                3.286917
# 2003-03-01  296029.8095        39                3.267289
# 2003-04-01  292949.1364        39                3.274399
# 2003-05-01  289680.9048        39                3.279752
# 2003-06-01  290310.0000        43                3.276182
# ...                 ...       ...                     ...
# 2013-04-01  400435.2727        44                3.366523
# 2013-05-01  397395.7727        44                3.360540
# 2013-06-01  396414.3000        44                3.352495
# 2013-07-01  321382.0455        44                3.351175
# 2013-08-01  399712.4091        44                3.347148
# 2013-09-01  415803.1500        44                3.343260
# 2013-10-01  359904.3182        44                3.351892
# 2013-11-01  394897.2778        44                3.358752
# 2013-12-01  377892.3684        44                3.359041
# 2014-01-01  381090.3333        44                3.523708
# 2014-02-01  398669.1053        44                3.510726
# 2014-03-01  403176.6190        44                3.488261
# 2014-04-01  403897.8182        44                3.476799
# 2014-05-01  409927.0476        44                3.464698
# 2014-06-01  410312.0000        44                3.458258
# 2014-07-01  414896.0000        44                3.459608
# 2014-08-01  419255.4762        44                3.465397
# 2014-09-01  430163.3810        44                3.462791
# 2014-10-01  441428.2727        46                3.471513
# 2014-11-01  424763.2941        46                3.490359
# 2014-12-01  400071.0000        46                3.510262
# 2015-01-01  410846.6842        46                3.526859
# 2015-02-01  420906.3158        46                3.511608
# 2015-03-01  423526.0000        46                3.490832
# 2015-04-01  429910.1364        46                3.483750
# 2015-05-01  424311.9500        46                3.466082
# 2015-06-01  432868.5455        46                3.453983
# 2015-07-01  427467.0909        46                3.453752
# 2015-08-01  429749.6190        46                     NaN
# 2015-09-01  445103.0000        46                     NaN
#
#             AVG_FARE_2010USD_BART           HH      HH_0VEH          POP  \
# MONTH
# 2001-01-01               2.555435  1452556.571  187359.1429  3870692.571
# 2001-02-01               2.545259  1452696.413  187278.4921  3870052.746
# 2001-03-01               2.539481  1452836.254  187197.8413  3869412.921
# 2001-04-01               2.529432  1452976.095  187117.1905  3868773.095
# 2001-05-01               2.518045  1453115.937  187036.5397  3868133.270
# 2001-06-01               2.513801  1453255.778  186955.8889  3867493.444
# 2001-07-01               2.443754  1453395.619  186875.2381  3866853.619
# 2001-08-01               2.443754  1453535.460  186794.5873  3866213.794
# 2001-09-01               2.432790  1453675.302  186713.9365  3865573.968
# 2001-10-01               2.441004  1453815.143  186633.2857  3864934.143
# 2001-11-01               2.445132  1453954.984  186552.6349  3864294.317
# 2001-12-01               2.454818  1454094.825  186471.9841  3863654.492
# 2002-01-01               2.449274  1454234.667  186391.3333  3863014.667
# 2002-02-01               2.439631  1454374.508  186310.6825  3862374.841
# 2002-03-01               2.425986  1454514.349  186230.0317  3861735.016
# 2002-04-01               2.412494  1454654.190  186149.3810  3861095.190
# 2002-05-01               2.412494  1454794.032  186068.7302  3860455.365
# 2002-06-01               2.411153  1454933.873  185988.0794  3859815.540
# 2002-07-01               2.405660  1455073.714  185907.4286  3859175.714
# 2002-08-01               2.397673  1455213.556  185826.7778  3858535.889
# 2002-09-01               2.393699  1455353.397  185746.1270  3857896.063
# 2002-10-01               2.389738  1455493.238  185665.4762  3857256.238
# 2002-11-01               2.389738  1455633.079  185584.8254  3856616.413
# 2002-12-01               2.395022  1455772.921  185504.1746  3855976.587
# 2003-01-01               2.511892  1455912.762  185423.5238  3855336.762
# 2003-02-01               2.492685  1456052.603  185342.8730  3854696.937
# 2003-03-01               2.477800  1456192.444  185262.2222  3854057.111
# 2003-04-01               2.483192  1456332.286  185181.5714  3853417.286
# 2003-05-01               2.487252  1456472.127  185100.9206  3852777.460
# 2003-06-01               2.484544  1456611.968  185020.2698  3852137.635
# ...                           ...          ...          ...          ...
# 2013-04-01               3.007663  1547380.500  198911.2500  4243306.000
# 2013-05-01               3.002317  1548822.667  198414.1667  4248174.333
# 2013-06-01               2.995130  1550264.833  197917.0833  4253042.667
# 2013-07-01               2.864840  1551707.000  197420.0000  4257911.000
# 2013-08-01               2.861398  1552599.417  198040.6667  4264194.250
# 2013-09-01               2.858074  1553491.833  198661.3333  4270477.500
# 2013-10-01               2.865453  1554384.250  199282.0000  4276760.750
# 2013-11-01               2.871318  1555276.667  199902.6667  4283044.000
# 2013-12-01               2.871564  1556169.083  200523.3333  4289327.250
# 2014-01-01               3.012335  1557061.500  201144.0000  4295610.500
# 2014-02-01               3.001236  1557953.917  201764.6667  4301893.750
# 2014-03-01               2.982032  1558846.333  202385.3333  4308177.000
# 2014-04-01               2.972233  1559738.750  203006.0000  4314460.250
# 2014-05-01               2.961889  1560631.167  203626.6667  4320743.500
# 2014-06-01               2.956383  1561523.583  204247.3333  4327026.750
# 2014-07-01               2.957537  1562416.000  204868.0000  4333310.000
# 2014-08-01               2.962486  1563308.417  205488.6667  4339593.250
# 2014-09-01               2.960258  1564200.833  206109.3333  4345876.500
# 2014-10-01               2.967714  1565093.250  206730.0000  4352159.750
# 2014-11-01               2.983825  1565985.667  207350.6667  4358443.000
# 2014-12-01               3.000840  1566878.083  207971.3333  4364726.250
# 2015-01-01               3.015029          NaN          NaN          NaN
# 2015-02-01               3.001991          NaN          NaN          NaN
# 2015-03-01               2.984229          NaN          NaN          NaN
# 2015-04-01               2.978175          NaN          NaN          NaN
# 2015-05-01               2.963072          NaN          NaN          NaN
# 2015-06-01               2.952729          NaN          NaN          NaN
# 2015-07-01               2.952531          NaN          NaN          NaN
# 2015-08-01                    NaN          NaN          NaN          NaN
# 2015-09-01                    NaN          NaN          NaN          NaN
#
#                 WORKERS  MEDIAN_HHINC_2010USD  SERVMILES_E_BART     ...       \
# MONTH                                                               ...
# 2001-01-01  1924489.571           85841.07733       25527.10573     ...
# 2001-02-01  1923471.413           85401.59874       25527.10573     ...
# 2001-03-01  1922453.254           85110.28356       25527.10573     ...
# 2001-04-01  1921435.095           84676.45762       25527.10573     ...
# 2001-05-01  1920416.937           84198.65633       25527.10573     ...
# 2001-06-01  1919398.778           83960.33478       25527.10573     ...
# 2001-07-01  1918380.619           84100.17146       25382.03327     ...
# 2001-08-01  1917362.460           84003.51416       25382.03327     ...
# 2001-09-01  1916344.302           83530.39581       25382.03327     ...
# 2001-10-01  1915326.143           83715.91371       25382.03327     ...
# 2001-11-01  1914307.984           83760.81533       25382.03327     ...
# 2001-12-01  1913289.825           83995.59646       25382.03327     ...
# 2002-01-01  1912271.667           83709.07751       25382.03327     ...
# 2002-02-01  1911253.508           83283.10372       25382.03327     ...
# 2002-03-01  1910235.349           82721.45711       25382.03327     ...
# 2002-04-01  1909217.190           82166.07175       25382.03327     ...
# 2002-05-01  1908199.032           82070.77501       25382.03327     ...
# 2002-06-01  1907180.873           81929.92478       25382.03327     ...
# 2002-07-01  1906162.714           81743.83157       25574.88408     ...
# 2002-08-01  1905144.556           81377.62666       25574.88408     ...
# 2002-09-01  1904126.397           81148.13637       25574.88408     ...
# 2002-10-01  1903108.238           80919.41921       25574.88408     ...
# 2002-11-01  1902090.079           80824.99280       25574.88408     ...
# 2002-12-01  1901071.921           80909.08877       25574.88408     ...
# 2003-01-01  1900053.762           80458.66590       25574.88408     ...
# 2003-02-01  1899035.603           79750.01365       25574.88408     ...
# 2003-03-01  1898017.444           79180.87879       25574.88408     ...
# 2003-04-01  1896999.286           79260.12360       25574.88408     ...
# 2003-05-01  1895981.127           79296.49063       25574.88408     ...
# 2003-06-01  1894962.968           79117.05939       25574.88408     ...
# ...                 ...                   ...               ...     ...
# 2013-04-01  2129032.750           72433.97142       27371.98200     ...
# 2013-05-01  2134242.167           72656.83749       27371.98200     ...
# 2013-06-01  2139451.583           72833.49059       27371.98200     ...
# 2013-07-01  2144661.000           73155.09277       27371.98200     ...
# 2013-08-01  2150448.583           73483.08528       27371.98200     ...
# 2013-09-01  2156236.167           73812.83194       27371.98200     ...
# 2013-10-01  2162023.750           74419.29605       27371.98200     ...
# 2013-11-01  2167811.333           74988.04236       27371.98200     ...
# 2013-12-01  2173598.917           75410.65739       27371.98200     ...
# 2014-01-01  2179386.500           75545.49403       27371.98200     ...
# 2014-02-01  2185174.083           75679.68713       27371.98200     ...
# 2014-03-01  2190961.667           75605.01979       27371.98200     ...
# 2014-04-01  2196749.250           75764.54768       27371.98200     ...
# 2014-05-01  2202536.833           75907.10578       27371.98200     ...
# 2014-06-01  2208324.417           76171.23183       27371.98200     ...
# 2014-07-01  2214112.000           76606.04950       27371.98200     ...
# 2014-08-01  2219899.583           77139.71183       27371.98200     ...
# 2014-09-01  2225687.167           77486.58939       27371.98200     ...
# 2014-10-01  2231474.750           78087.36894       27371.98200     ...
# 2014-11-01  2237262.333           78918.82139       28048.16263     ...
# 2014-12-01  2243049.917           79778.42457       30583.84000     ...
# 2015-01-01          NaN                   NaN       30583.84000     ...
# 2015-02-01          NaN                   NaN       30583.84000     ...
# 2015-03-01          NaN                   NaN       30583.84000     ...
# 2015-04-01          NaN                   NaN       30583.84000     ...
# 2015-05-01          NaN                   NaN       30583.84000     ...
# 2015-06-01          NaN                   NaN       30583.84000     ...
# 2015-07-01          NaN                   NaN       30583.84000     ...
# 2015-08-01          NaN                   NaN       30583.84000     ...
# 2015-09-01          NaN                   NaN       30770.42219     ...
#
#             EDHEALTH_EMP  LEISURE_EMP  OTHER_EMP  FUEL_PRICE_2010USD  \
# MONTH
# 2001-01-01      314779.0     179565.0  1317382.0            2.240335
# 2001-02-01      319473.0     181972.0  1321821.0            2.227694
# 2001-03-01      321266.0     184828.0  1331919.0            2.290702
# 2001-04-01      321919.0     185372.0  1308563.0            2.436951
# 2001-05-01      323980.0     188738.0  1302376.0            2.532738
# 2001-06-01      326345.0     190404.0  1306233.0            2.524794
# 2001-07-01      294427.0     190728.0  1285061.0            2.369747
# 2001-08-01      289318.0     191763.0  1279206.0            2.137563
# 2001-09-01      319470.0     188124.0  1269755.0            2.291850
# 2001-10-01      327365.0     183662.0  1252495.0            2.187923
# 2001-11-01      330262.0     181134.0  1242913.0            2.012163
# 2001-12-01      319334.0     181322.0  1246095.0            1.737537
# 2002-01-01      326094.0     174351.0  1205437.0            1.632650
# 2002-02-01      328612.0     175744.0  1209295.0            1.610279
# 2002-03-01      331746.0     178948.0  1218255.0            1.843963
# 2002-04-01      333807.0     183415.0  1211173.0            2.070198
# 2002-05-01      336480.0     187507.0  1213053.0            2.030177
# 2002-06-01      334343.0     189436.0  1220165.0            2.059350
# 2002-07-01      300514.0     188328.0  1211479.0            2.084911
# 2002-08-01      301141.0     190441.0  1212595.0            2.067127
# 2002-09-01      328878.0     188062.0  1209551.0            2.028764
# 2002-10-01      335367.0     186099.0  1195900.0            1.974892
# 2002-11-01      341219.0     185376.0  1197978.0            2.063895
# 2002-12-01      327654.0     185005.0  1205339.0            2.039529
# 2003-01-01      330132.0     178796.0  1168936.0            2.137357
# 2003-02-01      334932.0     179774.0  1172937.0            2.324660
# 2003-03-01      336223.0     181228.0  1178783.0            2.604360
# 2003-04-01      336968.0     182618.0  1170767.0            2.528168
# 2003-05-01      338713.0     185187.0  1169112.0            2.323158
# 2003-06-01      336318.0     188544.0  1173883.0            2.252968
# ...                  ...          ...        ...                 ...
# 2013-04-01      436226.0     225056.0  1124629.0            3.804453
# 2013-05-01      438191.0     229871.0  1128292.0            3.818285
# 2013-06-01      432229.0     231251.0  1137371.0            3.798872
# 2013-07-01      405461.0     231028.0  1145880.0            3.776839
# 2013-08-01      407526.0     233145.0  1150225.0            3.670675
# 2013-09-01      431484.0     232057.0  1145582.0            3.731600
# 2013-10-01      438110.0     231390.0  1152016.0            3.655337
# 2013-11-01      441126.0     231107.0  1157867.0            3.453246
# 2013-12-01      432875.0     231826.0  1160554.0            3.417052
# 2014-01-01      433988.0     225031.0  1148812.0            3.442607
# 2014-02-01      442094.0     228010.0  1156387.0            3.466145
# 2014-03-01      444537.0     230770.0  1161497.0            3.684822
# 2014-04-01      446190.0     236553.0  1167415.0            3.866789
# 2014-05-01      446975.0     239614.0  1175989.0            3.901910
# 2014-06-01      442253.0     243126.0  1184565.0            3.844339
# 2014-07-01      410977.0     242074.0  1193178.0            3.785434
# 2014-08-01      418426.0     243568.0  1200701.0            3.675338
# 2014-09-01      443228.0     241951.0  1198129.0            3.556232
# 2014-10-01      448146.0     239916.0  1204145.0            3.339265
# 2014-11-01      451434.0     238018.0  1209121.0            3.048985
# 2014-12-01      444142.0     238379.0  1213868.0            2.771064
# 2015-01-01      447125.0     232371.0  1201144.0            2.498658
# 2015-02-01      455237.0     235097.0  1207306.0            2.579824
# 2015-03-01      456091.0     237836.0  1214185.0            3.135284
# 2015-04-01           NaN          NaN        NaN                 NaN
# 2015-05-01           NaN          NaN        NaN                 NaN
# 2015-06-01           NaN          NaN        NaN                 NaN
# 2015-07-01           NaN          NaN        NaN                 NaN
# 2015-08-01           NaN          NaN        NaN                 NaN
# 2015-09-01           NaN          NaN        NaN                 NaN
#
#             FUEL_COST_2010USD  TOLL_BB_PK_2010USD  TOLL_BB_OP_2010USD  \
# MONTH
# 2001-01-01           0.101833            2.490645            2.490645
# 2001-02-01           0.101182            2.480728            2.480728
# 2001-03-01           0.103965            2.475096            2.475096
# 2001-04-01           0.110519            2.465302            2.465302
# 2001-05-01           0.114777            2.454204            2.454204
# 2001-06-01           0.114330            2.450067            2.450067
# 2001-07-01           0.107228            2.456969            2.456969
# 2001-08-01           0.096759            2.456969            2.456969
# 2001-09-01           0.103782            2.445945            2.445945
# 2001-10-01           0.099113            2.454204            2.454204
# 2001-11-01           0.091186            2.458354            2.458354
# 2001-12-01           0.078770            2.468093            2.468093
# 2002-01-01           0.074043            2.462518            2.462518
# 2002-02-01           0.073056            2.452823            2.452823
# 2002-03-01           0.083690            2.439105            2.439105
# 2002-04-01           0.093993            2.425539            2.425539
# 2002-05-01           0.092211            2.425539            2.425539
# 2002-06-01           0.093571            2.424191            2.424191
# 2002-07-01           0.094769            2.421499            2.421499
# 2002-08-01           0.093889            2.413459            2.413459
# 2002-09-01           0.092077            2.409459            2.409459
# 2002-10-01           0.089564            2.405472            2.405472
# 2002-11-01           0.093530            2.405472            2.405472
# 2002-12-01           0.092356            2.410790            2.410790
# 2003-01-01           0.096713            2.400176            2.400176
# 2003-02-01           0.105109            2.381824            2.381824
# 2003-03-01           0.117667            2.367600            2.367600
# 2003-04-01           0.114139            2.372753            2.372753
# 2003-05-01           0.104804            2.376632            2.376632
# 2003-06-01           0.101561            2.374045            2.374045
# ...                       ...                 ...                 ...
# 2013-04-01           0.162757            5.626501            3.751001
# 2013-05-01           0.163291            5.616502            3.744334
# 2013-06-01           0.162403            5.603056            3.735371
# 2013-07-01           0.161403            5.600849            3.733900
# 2013-08-01           0.156811            5.594120            3.729413
# 2013-09-01           0.159357            5.587622            3.725081
# 2013-10-01           0.156044            5.602048            3.734699
# 2013-11-01           0.147365            5.613514            3.742342
# 2013-12-01           0.145768            5.613995            3.742664
# 2014-01-01           0.146858            5.593187            3.728792
# 2014-02-01           0.147863            5.572580            3.715054
# 2014-03-01           0.157191            5.536922            3.691282
# 2014-04-01           0.164954            5.518728            3.679152
# 2014-05-01           0.166452            5.499521            3.666347
# 2014-06-01           0.163996            5.489299            3.659533
# 2014-07-01           0.161483            5.491442            3.660961
# 2014-08-01           0.156787            5.500631            3.667087
# 2014-09-01           0.151706            5.496494            3.664329
# 2014-10-01           0.142450            5.510338            3.673558
# 2014-11-01           0.130067            5.540252            3.693501
# 2014-12-01           0.118211            5.571845            3.714563
# 2015-01-01           0.106590            5.598189            3.732126
# 2015-02-01           0.110053            5.573981            3.715987
# 2015-03-01           0.133748            5.541003            3.694002
# 2015-04-01                NaN                 NaN                 NaN
# 2015-05-01                NaN                 NaN                 NaN
# 2015-06-01                NaN                 NaN                 NaN
# 2015-07-01                NaN                 NaN                 NaN
# 2015-08-01                NaN                 NaN                 NaN
# 2015-09-01                NaN                 NaN                 NaN
#
#             TOLL_BB_CARPOOL_2010USD  CASUAL_CARPOOL  BART_STRIKE
# MONTH
# 2001-01-01                 0.000000               1            0
# 2001-02-01                 0.000000               1            0
# 2001-03-01                 0.000000               1            0
# 2001-04-01                 0.000000               1            0
# 2001-05-01                 0.000000               1            0
# 2001-06-01                 0.000000               1            0
# 2001-07-01                 0.000000               1            0
# 2001-08-01                 0.000000               1            0
# 2001-09-01                 0.000000               1            0
# 2001-10-01                 0.000000               1            0
# 2001-11-01                 0.000000               1            0
# 2001-12-01                 0.000000               1            0
# 2002-01-01                 0.000000               1            0
# 2002-02-01                 0.000000               1            0
# 2002-03-01                 0.000000               1            0
# 2002-04-01                 0.000000               1            0
# 2002-05-01                 0.000000               1            0
# 2002-06-01                 0.000000               1            0
# 2002-07-01                 0.000000               1            0
# 2002-08-01                 0.000000               1            0
# 2002-09-01                 0.000000               1            0
# 2002-10-01                 0.000000               1            0
# 2002-11-01                 0.000000               1            0
# 2002-12-01                 0.000000               1            0
# 2003-01-01                 0.000000               1            0
# 2003-02-01                 0.000000               1            0
# 2003-03-01                 0.000000               1            0
# 2003-04-01                 0.000000               1            0
# 2003-05-01                 0.000000               1            0
# 2003-06-01                 0.000000               1            0
# ...                             ...             ...          ...
# 2013-04-01                 2.344376               0            0
# 2013-05-01                 2.340209               0            0
# 2013-06-01                 2.334607               0            0
# 2013-07-01                 2.333687               0            1
# 2013-08-01                 2.330883               0            0
# 2013-09-01                 2.328176               0            0
# 2013-10-01                 2.334187               0            1
# 2013-11-01                 2.338964               0            0
# 2013-12-01                 2.339165               0            0
# 2014-01-01                 2.330495               0            0
# 2014-02-01                 2.321909               0            0
# 2014-03-01                 2.307051               0            0
# 2014-04-01                 2.299470               0            0
# 2014-05-01                 2.291467               0            0
# 2014-06-01                 2.287208               0            0
# 2014-07-01                 2.288101               0            0
# 2014-08-01                 2.291929               0            0
# 2014-09-01                 2.290206               0            0
# 2014-10-01                 2.295974               0            0
# 2014-11-01                 2.308438               0            0
# 2014-12-01                 2.321602               0            0
# 2015-01-01                 2.332579               0            0
# 2015-02-01                 2.322492               0            0
# 2015-03-01                 2.308751               0            0
# 2015-04-01                      NaN               1            0
# 2015-05-01                      NaN               1            0
# 2015-06-01                      NaN               1            0
# 2015-07-01                      NaN               1            0
# 2015-08-01                      NaN               1            0
# 2015-09-01                      NaN               1            0
#
# [177 rows x 22 columns]

# %% [markdown]
# Take seasonal difference.. debate whether to us second diff or not.  Check this.
#
# Variables to use: POP, Cash_FARE_2010USD_BART, TOLL_BB_PK_2010USD

# %%
bart = bart[['RIDERS','POP','CASH_FARE_2010USD_BART','TOLL_BB_PK_2010USD']]

# %%
list(bart)
# Out:
# ['RIDERS', 'POP', 'CASH_FARE_2010USD_BART', 'TOLL_BB_PK_2010USD']

# %%
bart.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000000001C614DD8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000001D821DA0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000001D7D9668>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000001D9137F0>],
#       dtype=object)

# %%
bart = bart[np.isfinite(bart['POP'])]
bart = bart[np.isfinite(bart['TOLL_BB_PK_2010USD'])]

# %%
# shift moves things by the specified number of rows

bart['POP_DIFF'] = bart['POP'] - bart['POP'].shift(1)  
bart['CASH_FARE_2010USD_BART_DIFF'] = bart['CASH_FARE_2010USD_BART'] - bart['CASH_FARE_2010USD_BART'].shift(1)  
bart['TOLL_BB_PK_2010USD_DIFF'] = bart['TOLL_BB_PK_2010USD'] - bart['TOLL_BB_PK_2010USD'].shift(1)

# %%
# ACF plots

fig = sm.graphics.tsa.plot_acf(bart['POP_DIFF'][1:], lags=40)
fig = sm.graphics.tsa.plot_acf(bart['CASH_FARE_2010USD_BART_DIFF'][1:], lags=40)
fig = sm.graphics.tsa.plot_acf(bart['TOLL_BB_PK_2010USD_DIFF'][1:], lags=40)

# %%
# second shift

bart['POP_DIFF2'] = bart['POP_DIFF'] - bart['POP_DIFF'].shift(1)  
bart['CASH_FARE_2010USD_BART_DIFF2'] = bart['CASH_FARE_2010USD_BART_DIFF'] - bart['CASH_FARE_2010USD_BART_DIFF'].shift(1)  
bart['TOLL_BB_PK_2010USD_DIFF2'] = bart['TOLL_BB_PK_2010USD_DIFF'] - bart['TOLL_BB_PK_2010USD_DIFF'].shift(1)

# %%
# ACF plots for second diff

fig = sm.graphics.tsa.plot_acf(bart['POP_DIFF2'][2:], lags=40)
fig = sm.graphics.tsa.plot_acf(bart['CASH_FARE_2010USD_BART_DIFF2'][2:], lags=40)
fig = sm.graphics.tsa.plot_acf(bart['TOLL_BB_PK_2010USD_DIFF2'][2:], lags=40)

# %%
# estimate model on differences

mod = smf.ols(formula='RIDERS ~ POP_DIFF + CASH_FARE_2010USD_BART_DIFF + TOLL_BB_PK_2010USD_DIFF', data=bart)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 RIDERS   R-squared:                       0.481
# Model:                            OLS   Adj. R-squared:                  0.471
# Method:                 Least Squares   F-statistic:                     50.33
# Date:                Mon, 16 Apr 2018   Prob (F-statistic):           4.47e-23
# Time:                        08:09:33   Log-Likelihood:                -1928.4
# No. Observations:                 167   AIC:                             3865.
# Df Residuals:                     163   BIC:                             3877.
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                    3.192e+05   2816.129    113.330      0.000    3.14e+05    3.25e+05
# POP_DIFF                        8.2207      0.675     12.178      0.000       6.888       9.554
# CASH_FARE_2010USD_BART_DIFF -5.347e+04   4.84e+04     -1.104      0.271   -1.49e+05    4.22e+04
# TOLL_BB_PK_2010USD_DIFF     -2574.2133   9995.040     -0.258      0.797   -2.23e+04    1.72e+04
# ==============================================================================
# Omnibus:                        9.359   Durbin-Watson:                   0.354
# Prob(Omnibus):                  0.009   Jarque-Bera (JB):               13.017
# Skew:                          -0.334   Prob(JB):                      0.00149
# Kurtosis:                       4.194   Cond. No.                     1.03e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.03e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# estimate model on second differences

mod = smf.ols(formula='RIDERS ~ POP_DIFF2 + CASH_FARE_2010USD_BART_DIFF2 + TOLL_BB_PK_2010USD_DIFF2', data=bart)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 RIDERS   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.018
# Method:                 Least Squares   F-statistic:                   0.02420
# Date:                Mon, 16 Apr 2018   Prob (F-statistic):              0.995
# Time:                        08:09:33   Log-Likelihood:                -1971.7
# No. Observations:                 166   AIC:                             3951.
# Df Residuals:                     162   BIC:                             3964.
# Df Model:                           3
# Covariance Type:            nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     3.434e+05   2740.444    125.317      0.000    3.38e+05    3.49e+05
# POP_DIFF2                       -0.6529      3.025     -0.216      0.829      -6.626       5.321
# CASH_FARE_2010USD_BART_DIFF2 -6826.2415   4.79e+04     -0.142      0.887   -1.01e+05    8.78e+04
# TOLL_BB_PK_2010USD_DIFF2      -741.7159   9780.105     -0.076      0.940   -2.01e+04    1.86e+04
# ==============================================================================
# Omnibus:                        8.978   Durbin-Watson:                   0.159
# Prob(Omnibus):                  0.011   Jarque-Bera (JB):                9.208
# Skew:                           0.544   Prob(JB):                       0.0100
# Kurtosis:                       2.614   Cond. No.                     1.59e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.59e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# # Results
# ##### Based on the model of the second differences, we can estimate ridership for BART using the following equation:
#
# ##### Riders = 343,400 - .6529*(Population Second Difference) - 6826.2*(Cash Fare 2010 Second Difference) - 741.7*(Toll 2010 Second Difference)
